# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("C:\\Users\\naval\\Downloads\\archive (7)\\student_performance_large_dataset.csv")
df.head()
# Out:
#   Student_ID  Age  Gender  Study_Hours_per_Week Preferred_Learning_Style  \
# 0     S00001   18  Female                    48              Kinesthetic
# 1     S00002   29  Female                    30          Reading/Writing
# 2     S00003   20  Female                    47              Kinesthetic
# 3     S00004   23  Female                    13                 Auditory
# 4     S00005   19  Female                    24                 Auditory
#
#    Online_Courses_Completed Participation_in_Discussions  \
# 0                        14                          Yes
# 1                        20                           No
# 2                        11                           No
# 3                         0                          Yes
# 4                        19                          Yes
#
#    Assignment_Completion_Rate (%)  Exam_Score (%)  Attendance_Rate (%)  \
# 0                             100              69                   66
# 1                              71              40                   57
# 2                              60              43                   79
# 3                              63              70                   60
# 4                              59              63                   93
#
#   Use_of_Educational_Tech Self_Reported_Stress_Level  \
# 0                     Yes                       High
# 1                     Yes                     Medium
# 2                     Yes                        Low
# 3                     Yes                        Low
# 4                     Yes                     Medium
#
#    Time_Spent_on_Social_Media (hours/week)  Sleep_Hours_per_Night Final_Grade
# 0                                        9                      8           C
# 1                                       28                      8           D
# 2                                       13                      7           D
# 3                                       24                     10           B
# 4                                       26                      8           C

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 15 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Student_ID                               10000 non-null  object
#  1   Age                                      10000 non-null  int64
#  2   Gender                                   10000 non-null  object
#  3   Study_Hours_per_Week                     10000 non-null  int64
#  4   Preferred_Learning_Style                 10000 non-null  object
#  5   Online_Courses_Completed                 10000 non-null  int64
#  6   Participation_in_Discussions             10000 non-null  object
#  7   Assignment_Completion_Rate (%)           10000 non-null  int64
#  8   Exam_Score (%)                           10000 non-null  int64
#  9   Attendance_Rate (%)                      10000 non-null  int64
#  10  Use_of_Educational_Tech                  10000 non-null  object
#  11  Self_Reported_Stress_Level               10000 non-null  object
#  12  Time_Spent_on_Social_Media (hours/week)  10000 non-null  int64
#  13  Sleep_Hours_per_Night                    10000 non-null  int64
#  14  Final_Grade                              10000 non-null  object
# dtypes: int64(8), object(7)
# memory usage: 1.1+ MB

# %%
df.isnull().sum()
#there is no null values
# Out:
# Student_ID                                 0
# Age                                        0
# Gender                                     0
# Study_Hours_per_Week                       0
# Preferred_Learning_Style                   0
# Online_Courses_Completed                   0
# Participation_in_Discussions               0
# Assignment_Completion_Rate (%)             0
# Exam_Score (%)                             0
# Attendance_Rate (%)                        0
# Use_of_Educational_Tech                    0
# Self_Reported_Stress_Level                 0
# Time_Spent_on_Social_Media (hours/week)    0
# Sleep_Hours_per_Night                      0
# Final_Grade                                0
# dtype: int64

# %%
numerical_col=df.select_dtypes(include=['int64']).columns
categorical_col=df.select_dtypes(include=['object']).columns
numerical_col
# Out:
# Index(['Age', 'Study_Hours_per_Week', 'Online_Courses_Completed',
#        'Assignment_Completion_Rate (%)', 'Exam_Score (%)',
#        'Attendance_Rate (%)', 'Time_Spent_on_Social_Media (hours/week)',
#        'Sleep_Hours_per_Night'],
#       dtype='object')

# %%
categorical_col
# Out:
# Index(['Student_ID', 'Gender', 'Preferred_Learning_Style',
#        'Participation_in_Discussions', 'Use_of_Educational_Tech',
#        'Self_Reported_Stress_Level', 'Final_Grade'],
#       dtype='object')

# %%
for col in numerical_col:
    plt.figure(figsize=(2,1))
    sns.histplot(df[col],kde=True)
    plt.title(f'Plotting of{col}')

# %%
for col in numerical_col:
    plt.figure(figsize=(2,2))
    sns.boxplot(df[col])
    plt.title(f'Plotting of{col}')

# %%
df[categorical_col].nunique()
# Out:
# Student_ID                      10000
# Gender                              3
# Preferred_Learning_Style            4
# Participation_in_Discussions        2
# Use_of_Educational_Tech             2
# Self_Reported_Stress_Level          3
# Final_Grade                         4
# dtype: int64

# %%
for col in categorical_col:
    plt.figure(figsize=(6,4))
    sns.countplot(y=df[col],order=df[col].value_counts().index)
    plt.show()

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(df[numerical_col])
plt.show()

# %%
sns.pairplot(df[numerical_col])
plt.show()

# %%
Q1 = df[numerical_col].quantile(0.25)
Q3 = df[numerical_col].quantile(0.75)
IQR = Q3 - Q1
df = df[~((df[numerical_col] < (Q1 - 1.5 * IQR)) | (df[numerical_col] > (Q3 + 1.5 * IQR))).any(axis=1)]

# %%
print(Q1)

print(Q3)

print(IQR)
# Out:
# Age                                        20.0
# Study_Hours_per_Week                       16.0
# Online_Courses_Completed                    5.0
# Assignment_Completion_Rate (%)             62.0
# Exam_Score (%)                             55.0
# Attendance_Rate (%)                        62.0
# Time_Spent_on_Social_Media (hours/week)     7.0
# Sleep_Hours_per_Night                       5.0
# Name: 0.25, dtype: float64
# Age                                        27.0
# Study_Hours_per_Week                       38.0
# Online_Courses_Completed                   15.0
# Assignment_Completion_Rate (%)             88.0
# Exam_Score (%)                             85.0
# Attendance_Rate (%)                        88.0
# Time_Spent_on_Social_Media (hours/week)    23.0
# Sleep_Hours_per_Night                       9.0
# Name: 0.75, dtype: float64
# Age                                         7.0
# Study_Hours_per_Week                       22.0
# Online_Courses_Completed                   10.0
# Assignment_Completion_Rate (%)             26.0
# Exam_Score (%)                             30.0
# Attendance_Rate (%)                        26.0
# Time_Spent_on_Social_Media (hours/week)    16.0
# Sleep_Hours_per_Night                       4.0
# dtype: float64

# %%
df.to_csv('AFter_Analysis_dataset.csv',index=False)
